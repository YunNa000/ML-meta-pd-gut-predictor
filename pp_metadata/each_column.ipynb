# %% [markdown]
# ### 전체 칼럼 톺아보기 (65개)

# %%
import pandas as pd

# 1. CSV 불러오기
df = pd.read_csv("all_column_delete11.csv") 
                                             # sex, age none 값 -> 어차피 혼동변수임으로 일단 대기 

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1425 entries, 0 to 1424
# Data columns (total 65 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   sample_id                                            1425 non-null   object
#  1   alias                                                1424 non-null   object
#  2   project_id                                           1425 non-null   object
#  3   center_name                                          1424 non-null   object
#  4   parkinson                                            1249 non-null   object
#  5   ENA-CHECKLIST                                        324 non-null    object
#  6   collection_date                                      1224 non-null   object
#  7   ENA-FIRST-PUBLIC                                     1424 non-null   object
# ...

# %% [markdown]
# 1. sample_id
#
# - 데이터 시각화 및 수치화 확인 (이상치 확인)
#
# - 결측치 처리
#
# - 중복값 처리
#
# - 이상치 처리
#
# - 피쳐스케일링 (범주형, 연속형)
#
# - 파생변수 고려해보기

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 데이터 불러오기
df = pd.read_csv("all_column_delete11.csv")

# 1. sample_id 값 분포 및 시각화

# 2. 결측치 확인
missing_count = df['sample_id'].isna().sum()
print(f"[결측치] sample_id: {missing_count}개")

# 3. 중복값 확인 및 제거
duplicate_count = df['sample_id'].duplicated().sum()
print(f"[중복값] sample_id: {duplicate_count}개")

# 만약 중복 제거하려면 아래 실행
# df = df.drop_duplicates(subset=['sample_id'])

# 4. 이상치 처리

# 5. 피처 스케일링
# sample_id는 수치형 피처가 아니므로 스케일링 부적절 —> 필요 시 encoding 고려

# 예시: sample_id prefix에서 파생변수 생성 (ex: 실험 배치 정보 포함 시)
# 예: sample_id가 "PRJEB14928_S01" 형식이라면 prefix로 배치 추출
# df['sample_prefix'] = df['sample_id'].astype(str).str.extract(r'(^[A-Za-z]+)')
# Out:
# [결측치] sample_id: 0개
# [중복값] sample_id: 0개

# %%
2. alias   

- unique한 값

- 데이터 시각화 및 수치화 확인 (이상치 확인)

- 결측치 처리

- 중복값 처리

- 이상치 처리

- 피쳐스케일링 (범주형, 연속형)

- 파생변수 고려해보기

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 데이터 불러오기
df = pd.read_csv("all_column_delete11.csv")

# 1. alias unique한 값 
unique_alias = df["alias"].dropna().unique()
print("Unique alias 값 수:", len(unique_alias))
print("Unique alias 값 전체:")
for val in unique_alias:
    print(val)

# 2. 시각화 및 수치화 (이상치 확인용)

# 3. 결측치 확인
missing_count = df['sample_id'].isna().sum()
print(f"[결측치] sample_id: {missing_count}개")

# 4. 중복값 확인 및 제거
duplicate_count = df['sample_id'].duplicated().sum()
print(f"[중복값] sample_id: {duplicate_count}개")

# 5. 이상치 처리

# 6. 피처 스케일링

# 7. 파생변수 고려
# Out:
# Unique alias 값 수: 1424
# Unique alias 값 전체:
# 11P
# 25P
# 27P
# 30P
# 36P
# 43P
# 45P
# 15K
# 21K
# 30K
# 36K
# PAR007
# PAR009
# PAR010
# PAR011
# PAR014
# PAR017
# PAR018
# 12P
# 23P
# 29P
# 38P
# 44P
# 06K
# 12K
# 23K
# 25K
# 35K
# 43K
# 45K
# 52K
# PAR002
# PAR003
# PAR004
# PAR005
# PAR006
# PAR008
# PAR012
# PAR013
# PAR015
# PAR016
# PAR019
# PAR020
# 06P
# 08P
# 15P
# 21P
# 35P
# 46P
# 52P
# 08K
# 11K
# 27K
# 29K
# 38K
# 44K
# 46K
# PAR001
# PF1
# PF2
# PF5
# PF9
# PF12
# PF20
# PF23
# PF24
# PF31
# PF34
# PF36
# PF39
# PF43
# PF44
# PF49
# PF55
# PF56
# PF65
# PF67
# PF68
# PF70
# PF74
# PF76
# PF77
# PF78
# PF79
# PF81
# PF87
# PF88
# PF93
# PF94
# PF99
# PF100
# PF102
# PF103
# PF104
# PF105
# PF106
# PF109
# PF121
# PF125
# PF128
# PF131
# PF133
# PF134
# PF135
# PF139
# PF140
# PF144
# PF149
# PF150
# PF151
# PF154
# PF159
# PF161
# PF163
# PF164
# PF168
# PF169
# PF170
# PF178
# PF180
# PF182
# PF183
# PF191
# PF192
# PF205
# PF206
# PF214
# PF215
# PF219
# PF220
# ...

# %% [markdown]
# 3. project_id
#
# - unique한 값
#
# - 데이터 시각화 및 수치화 확인 (이상치 확인)
#
# - 결측치 처리
#
# - 중복값 처리
#
# - 이상치 처리
#
# - 피쳐스케일링 (범주형, 연속형)
#
# - 파생변수 고려해보기

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 데이터 불러오기
df = pd.read_csv("all_column_delete11.csv")

# 1. alias unique한 값 
unique_alias = df["project_id"].dropna().unique()
print("Unique project_id 값 수:", len(unique_alias))
print("Unique project_id 값 전체:")
for val in unique_alias:
    print(val)

# 2. 시각화 및 수치화 (이상치 확인용)

# 3. 결측치 확인
missing_count = df['project_id'].isna().sum()
print(f"[결측치] project_id: {missing_count}개")

# 4. 중복값 확인 및 제거
duplicate_count = df['project_id'].duplicated().sum()
print(f"[중복값] project_id: {duplicate_count}개")

# 5. 이상치 처리

# 6. 피처 스케일링

# 7. 파생변수 고려
# Out:
# Unique project_id 값 수: 6
# Unique project_id 값 전체:
# PRJEB14928
# PRJEB27564
# PRJNA381395
# PRJNA391524
# PRJNA494620
# PRJNA834801
# [결측치] project_id: 0개
# [중복값] project_id: 1419개

# %% [markdown]
# 4. center_name
#
# - unique한 값
#
# - 데이터 시각화 및 수치화 확인 (이상치 확인)
#
# - 결측치 처리
#
# - 중복값 처리
#
# - 이상치 처리
#
# - 피쳐스케일링 (범주형, 연속형)
#
# - 파생변수 고려해보기

# %%
# ! 이거 범주화 카테고리 정리?

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 데이터 불러오기
df = pd.read_csv("all_column_delete11.csv")

# 1. alias unique한 값 
unique_alias = df["center_name"].dropna().unique()
print("Unique center_name 값 수:", len(unique_alias))
print("Unique center_name 값 전체:")
for val in unique_alias:
    print(val)

# 2. 시각화 및 수치화 (이상치 확인용)

# 3. 결측치 확인
missing_count = df['center_name'].isna().sum()
print(f"[결측치] center_name: {missing_count}개")

# 4. 중복값 확인 및 제거
duplicate_count = df['center_name'].duplicated().sum()
print(f"[중복값] center_name: {duplicate_count}개")

# 5. 이상치 처리

# 6. 피처 스케일링

# 7. 파생변수 고려
# Out:
# Unique center_name 값 수: 6
# Unique center_name 값 전체:
# University of Lubeck
# UH/IB
# University Luxembourg
# Ruijin Hospital, Shanghai Jiao Tong University School of Medicine
# Universiti Malaya
# pda|wallenz
# [결측치] center_name: 1개
# [중복값] center_name: 1418개

# %%
# center_name의 결측치의 sample_id 를 확인한 후 같은 sample_id를 가진 행의 center_name 값으로 대체 

def fill_center_name(group):
    if group['center_name'].isna().any():
        known = group['center_name'].dropna().unique()
        if len(known) == 1:
            group['center_name'] = group['center_name'].fillna(known[0])
        elif len(known) > 1:
            # 여러 값이 존재하는 경우 → 채우지 않고 그대로 둠
            pass
    return group

df = df.groupby('sample_id', group_keys=False).apply(fill_center_name)

# 결측치 다시 확인
print(f"[처리 후 결측치 수] center_name: {df['center_name'].isna().sum()}개")
# Out:
# [처리 후 결측치 수] center_name: 1개
# C:\Users\user\AppData\Local\Temp\ipykernel_28568\1253464342.py:13: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby('sample_id', group_keys=False).apply(fill_center_name)

# %% [markdown]
# 5. parkinson
#
# - unique한 값
#
# - 데이터 시각화 및 수치화 확인 (이상치 확인)
#
# - 결측치 처리
#
# - 중복값 처리
#
# - 이상치 처리
#
# - 피쳐스케일링 (범주형, 연속형)
#
# - 파생변수 고려해보기

# %%
# !! NAN 값은 어떻게 할지 

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 데이터 불러오기
df = pd.read_csv("all_column_delete11.csv")

# 1. alias unique한 값 
unique_alias = df["parkinson"].dropna().unique()
print("Unique parkinson 값 수:", len(unique_alias))
print("Unique parkinson 값 전체:")
for val in unique_alias:
    print(val)

# 2. 시각화 및 수치화 (이상치 확인용)

# 3. 결측치 확인
missing_count = df['parkinson'].isna().sum()
print(f"[결측치] parkinson: {missing_count}개")

# 4. 중복값 확인 및 제거
duplicate_count = df['parkinson'].duplicated().sum()
print(f"[중복값] parkinson: {duplicate_count}개")

# 5. 이상치 처리

# 6. 피처 스케일링
# 라벨 종류 확인
print(df["parkinson"].unique())

# 라벨 통일 (의미 기준: PD 관련 vs Control 관련)
df["parkinson"] = df["parkinson"].replace({
    "Parkinson disease": "PD",
    "PD": "PD",
    "yes": "PD",
    "gut patient": "PD",
    "Control": "Control",
    "no": "Control",
    "gut control": "Control"
})

# 혹시 모를 공백/대소문자 정리
df["parkinson"] = df["parkinson"].str.strip().str.capitalize()

# 최종 확인
print(df["parkinson"].value_counts(dropna=False))

# 7. 파생변수 고려
# Out:
# Unique parkinson 값 수: 7
# Unique parkinson 값 전체:
# gut patient
# gut control
# no
# yes
# Parkinson disease
# Control
# PD
# [결측치] parkinson: 176개
# [중복값] parkinson: 1417개
# ['gut patient' 'gut control' 'no' 'yes' nan 'Parkinson disease' 'Control'
#  'PD']
# parkinson
# Pd         760
# Control    489
# NaN        176
# Name: count, dtype: int64

# %% [markdown]
# 5. ENA-CHECKLIST
# 6. collection_date
# 7. ENA-FIRST-PUBLIC
# 8. ENA-LAST-UPDATE
# 9. sequencing method
# 10. geo_location
# 11. geo_coord
# 12. sex
# 13. age
#
#
# - unique한 값
#
# - 데이터 시각화 및 수치화 확인 (이상치 확인)
#
# - 결측치 처리
#
# - 중복값 처리
#
# - 이상치 처리
#
# - 피쳐스케일링 (범주형, 연속형)
#
# - 파생변수 고려해보기

# %% [markdown]
# target_cols = [
#     "Sleep_aid", "Pain_med", "Ulcer_past_3_months", "SIBO", "Day_of_stool_collection_digestion_issue",
#     "Cholesterol_med", "Antibiotics_current", "Constipation", "How_often_do_you_eat_NUTS",
#     "Indigestion_drugs", "Asthma_or_COPD_med", "Thyroid_med", "Diarrhea", "GI_cancer_past_3_months",
#     "Anti_inflammatory_drugs", "Day_of_stool_collection_abdominal_pain", "Day_of_stool_collection_excess_gas",
#     "Co_Q_10", "Do_you_drink_alcohol", "Radiation_Chemo", "Blood_thinners", "Diabetes_med", "Laxatives",
#     "Colitis", "Depression_anxiety_mood_med", "Birth_control_or_estrogen", "Blood_pressure_med",
#     "Day_of_stool_collection_constipation", "Loss_10lbs_in_last_year", "Do_you_smoke", "IBD",
#     "Jewish_ancestry", "Hispanic_or_Latino", "How_often_do_you_eat_POULTRY_BEEF_PORK_SEAFOOD_EGGS",
#     "Day_of_stool_collection_diarrhea", "Race", "IBS", "BMI", "Intestinal_disease", "Probiotic",
#     "Antihistamines", "Gained_10lbs_in_last_year", "Celiac_disease", "Bristol_stool_chart",
#     "How_often_do_you_eat_FRUITS_or_VEGETABLES", "Do_you_drink_caffeinated_beverages",
#     "How_often_do_you_eat_GRAINS", "How_often_do_you_eat_YOGURT", "Crohns_disease",
#     "Day_of_stool_collection_bloating", "Antibiotics_past_3_months"
# ]
#
# - unique한 값
#
# - 데이터 시각화 및 수치화 확인 (이상치 확인)
#
# - 결측치 처리
#
# - 중복값 처리
#
# - 이상치 처리
#
# - 피쳐스케일링 (범주형, 연속형)
#
# - 파생변수 고려해보기

# %%
import pandas as pd

# 1. 데이터 불러오기
df = pd.read_csv("all_column_delete11.csv")

# 2. 분석 대상 컬럼 정의
target_cols = [
    "Sleep_aid", "Pain_med", "Ulcer_past_3_months", "SIBO", "Day_of_stool_collection_digestion_issue",
    "Cholesterol_med", "Antibiotics_current", "Constipation", "How_often_do_you_eat_NUTS",
    "Indigestion_drugs", "Asthma_or_COPD_med", "Thyroid_med", "Diarrhea", "GI_cancer_past_3_months",
    "Anti_inflammatory_drugs", "Day_of_stool_collection_abdominal_pain", "Day_of_stool_collection_excess_gas",
    "Co_Q_10", "Do_you_drink_alcohol", "Radiation_Chemo", "Blood_thinners", "Diabetes_med", "Laxatives",
    "Colitis", "Depression_anxiety_mood_med", "Birth_control_or_estrogen", "Blood_pressure_med",
    "Day_of_stool_collection_constipation", "Loss_10lbs_in_last_year", "Do_you_smoke", "IBD",
    "Jewish_ancestry", "Hispanic_or_Latino", "How_often_do_you_eat_POULTRY_BEEF_PORK_SEAFOOD_EGGS",
    "Day_of_stool_collection_diarrhea", "Race", "IBS", "BMI", "Intestinal_disease", "Probiotic",
    "Antihistamines", "Gained_10lbs_in_last_year", "Celiac_disease", "Bristol_stool_chart",
    "How_often_do_you_eat_FRUITS_or_VEGETABLES", "Do_you_drink_caffeinated_beverages",
    "How_often_do_you_eat_GRAINS", "How_often_do_you_eat_YOGURT", "Crohns_disease",
    "Day_of_stool_collection_bloating", "Antibiotics_past_3_months"
]

# 3. 유니크 값 출력
print("▶ 각 칼럼의 유니크 값 확인:")
for col in target_cols:
    uniques = df[col].unique()
    print(f"\n{col} ({len(uniques)}개):")
    print(uniques)
# Out:
# ▶ 각 칼럼의 유니크 값 확인:
#
# Sleep_aid (3개):
# ['unknown' 'Y' 'N']
#
# Pain_med (3개):
# ['unknown' 'N' 'Y']
#
# Ulcer_past_3_months (3개):
# ['unknown' 'N' 'Y']
#
# SIBO (3개):
# ['unknown' 'N' 'Y']
#
# Day_of_stool_collection_digestion_issue (3개):
# ['unknown' 'N' 'Y']
#
# Cholesterol_med (3개):
# ['unknown' 'N' 'Y']
#
# Antibiotics_current (3개):
# ['unknown' 'N' 'Y']
#
# Constipation (3개):
# ['unknown' 'Y' 'N']
#
# How_often_do_you_eat_NUTS (5개):
# ['unknown' 'Few times a month' 'Less than once a month or never'
#  'At least once a day' 'Few times a week']
#
# Indigestion_drugs (3개):
# ['unknown' 'Y' 'N']
#
# Asthma_or_COPD_med (3개):
# ['unknown' 'N' 'Y']
#
# Thyroid_med (3개):
# ['unknown' 'N' 'Y']
#
# Diarrhea (3개):
# ['unknown' 'N' 'Y']
#
# GI_cancer_past_3_months (3개):
# ['unknown' 'N' 'Y']
#
# Anti_inflammatory_drugs (3개):
# ['unknown' 'N' 'Y']
#
# Day_of_stool_collection_abdominal_pain (3개):
# ['unknown' 'N' 'Y']
#
# Day_of_stool_collection_excess_gas (3개):
# ['unknown' 'N' 'Y']
#
# ...

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler

# 데이터 로드
df = pd.read_csv("all_column_delete11.csv")

# 대상 칼럼 정의
target_cols = [
    "Sleep_aid", "Pain_med", "Ulcer_past_3_months", "SIBO", "Day_of_stool_collection_digestion_issue",
    "Cholesterol_med", "Antibiotics_current", "Constipation", "How_often_do_you_eat_NUTS",
    "Indigestion_drugs", "Asthma_or_COPD_med", "Thyroid_med", "Diarrhea", "GI_cancer_past_3_months",
    "Anti_inflammatory_drugs", "Day_of_stool_collection_abdominal_pain", "Day_of_stool_collection_excess_gas",
    "Co_Q_10", "Do_you_drink_alcohol", "Radiation_Chemo", "Blood_thinners", "Diabetes_med", "Laxatives",
    "Colitis", "Depression_anxiety_mood_med", "Birth_control_or_estrogen", "Blood_pressure_med",
    "Day_of_stool_collection_constipation", "Loss_10lbs_in_last_year", "Do_you_smoke", "IBD",
    "Jewish_ancestry", "Hispanic_or_Latino", "How_often_do_you_eat_POULTRY_BEEF_PORK_SEAFOOD_EGGS",
    "Day_of_stool_collection_diarrhea", "Race", "IBS", "BMI", "Intestinal_disease", "Probiotic",
    "Antihistamines", "Gained_10lbs_in_last_year", "Celiac_disease", "Bristol_stool_chart",
    "How_often_do_you_eat_FRUITS_or_VEGETABLES", "Do_you_drink_caffeinated_beverages",
    "How_often_do_you_eat_GRAINS", "How_often_do_you_eat_YOGURT", "Crohns_disease",
    "Day_of_stool_collection_bloating", "Antibiotics_past_3_months"
]

# 1. BMI 스케일링
df["BMI"] = df["BMI"].replace("unknown", np.nan).astype(float)
scaler = StandardScaler()
df["BMI_scaled"] = scaler.fit_transform(df[["BMI"]])

# 2. 이진 범주형 매핑
binary_map = {
    "Y": 1, "Yes": 1,
    "N": 0, "No": 0,
    "unknown": np.nan,
    "": np.nan,
    np.nan: np.nan
}

# race, stool 제외하고 3개 이하 unique 값이면 이진 매핑
for col in target_cols:
    if col in ["BMI", "Race", "Bristol_stool_chart"]:
        continue
    if df[col].nunique(dropna=False) <= 3:
        df[col + "_bin"] = df[col].map(binary_map)

# 3. 5단계 frequency 매핑
frequency_map = {
    "At least once a day": 4,
    "Few times a week": 3,
    "Few times a month": 2,
    "Less than once a month or never": 1,
    "unknown": np.nan,
    np.nan: np.nan
}

# 적용할 5단계 frequency 대상 컬럼
freq_cols = [
    "How_often_do_you_eat_YOGURT",
    "How_often_do_you_eat_GRAINS",
    "How_often_do_you_eat_FRUITS_or_VEGETABLES",
    "How_often_do_you_eat_POULTRY_BEEF_PORK_SEAFOOD_EGGS",
    "How_often_do_you_eat_NUTS"
]

for col in freq_cols:
    df[col + "_freq"] = df[col].map(frequency_map)

# 최종 확인용 출력 (옵션)
print("▶ 스케일링 및 매핑 완료 변수 예시:")
print("BMI_scaled:", df["BMI_scaled"].head())
print("Sleep_aid_bin:", df["Sleep_aid_bin"].unique())
print("How_often_do_you_eat_YOGURT_freq:", df["How_often_do_you_eat_YOGURT_freq"].unique())
# Out:
# ▶ 스케일링 및 매핑 완료 변수 예시:
# BMI_scaled: 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: BMI_scaled, dtype: float64
# Sleep_aid_bin: [nan  1.  0.]
# How_often_do_you_eat_YOGURT_freq: [nan  1.  2.  3.  4.]

# %% [markdown]
# 전체 정리한 코드

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler

# 데이터 불러오기
df = pd.read_csv("all_column_delete11.csv")

# 1. center_name 보정
def fill_center_name(group):
    if group['center_name'].isna().any():
        known = group['center_name'].dropna().unique()
        if len(known) == 1:
            group['center_name'] = group['center_name'].fillna(known[0])
    return group

df = df.groupby('sample_id', group_keys=False).apply(fill_center_name).reset_index(drop=True)
print(f"[center_name 결측치 처리 후] 남은 결측치 수: {df['center_name'].isna().sum()}")

# 2. parkinson 라벨 통일
df["parkinson"] = df["parkinson"].replace({
    "Parkinson disease": "PD",
    "PD": "PD",
    "yes": "PD",
    "gut patient": "PD",
    "Control": "Control",
    "no": "Control",
    "gut control": "Control"
})
df["parkinson"] = df["parkinson"].astype(str).str.strip().str.capitalize()
print("\n[parkinson 라벨 정리 결과]:")
print(df["parkinson"].value_counts(dropna=False))

# 3. 분석 대상 칼럼 정의
target_cols = [
    "Sleep_aid", "Pain_med", "Ulcer_past_3_months", "SIBO", "Day_of_stool_collection_digestion_issue",
    "Cholesterol_med", "Antibiotics_current", "Constipation", "How_often_do_you_eat_NUTS",
    "Indigestion_drugs", "Asthma_or_COPD_med", "Thyroid_med", "Diarrhea", "GI_cancer_past_3_months",
    "Anti_inflammatory_drugs", "Day_of_stool_collection_abdominal_pain", "Day_of_stool_collection_excess_gas",
    "Co_Q_10", "Do_you_drink_alcohol", "Radiation_Chemo", "Blood_thinners", "Diabetes_med", "Laxatives",
    "Colitis", "Depression_anxiety_mood_med", "Birth_control_or_estrogen", "Blood_pressure_med",
    "Day_of_stool_collection_constipation", "Loss_10lbs_in_last_year", "Do_you_smoke", "IBD",
    "Jewish_ancestry", "Hispanic_or_Latino", "How_often_do_you_eat_POULTRY_BEEF_PORK_SEAFOOD_EGGS",
    "Day_of_stool_collection_diarrhea", "Race", "IBS", "BMI", "Intestinal_disease", "Probiotic",
    "Antihistamines", "Gained_10lbs_in_last_year", "Celiac_disease", "Bristol_stool_chart",
    "How_often_do_you_eat_FRUITS_or_VEGETABLES", "Do_you_drink_caffeinated_beverages",
    "How_often_do_you_eat_GRAINS", "How_often_do_you_eat_YOGURT", "Crohns_disease",
    "Day_of_stool_collection_bloating", "Antibiotics_past_3_months"
]

# 4. BMI 스케일링
df["BMI"] = df["BMI"].astype(str).str.strip().replace("unknown", np.nan).astype(float)
scaler = StandardScaler()
df["BMI_scaled"] = scaler.fit_transform(df[["BMI"]])
print(f"\n[BMI 스케일링 완료]")

# 5. 이진 매핑
binary_map = {
    "Y": 1, "Yes": 1,
    "N": 0, "No": 0,
    "unknown": np.nan,
    "": np.nan,
    np.nan: np.nan
}

for col in target_cols:
    if col in ["BMI", "Race", "Bristol_stool_chart"]:
        continue
    df[col] = df[col].astype(str).str.strip().replace("unknown", np.nan)
    if df[col].nunique(dropna=False) <= 3:
        df[col + "_bin"] = df[col].map(binary_map)

# 6. 5단계 빈도 매핑
frequency_map = {
    "At least once a day": 4,
    "Few times a week": 3,
    "Few times a month": 2,
    "Less than once a month or never": 1,
    "unknown": np.nan,
    np.nan: np.nan
}

freq_cols = [
    "How_often_do_you_eat_YOGURT",
    "How_often_do_you_eat_GRAINS",
    "How_often_do_you_eat_FRUITS_or_VEGETABLES",
    "How_often_do_you_eat_POULTRY_BEEF_PORK_SEAFOOD_EGGS",
    "How_often_do_you_eat_NUTS"
]

for col in freq_cols:
    df[col] = df[col].astype(str).str.strip().replace("unknown", np.nan)
    df[col + "_freq"] = df[col].map(frequency_map)

# 7. CSV 저장
df.to_csv("each_column_pp.csv", index=False)
print("\n✅ 최종 저장 완료: each_column_pp.csv")
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_28568\705552221.py:16: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby('sample_id', group_keys=False).apply(fill_center_name).reset_index(drop=True)
# C:\Users\user\AppData\Local\Temp\ipykernel_28568\705552221.py:92: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col + "_freq"] = df[col].map(frequency_map)
# ...
